# %%
import pandas as pd
df = pd.read_csv("../data/dummy_retail_sales.csv", parse_dates=["Date"])
df.head()
# Out:
#    InvoiceID       Date                             Product   Category  \
# 0  INV100000 2024-11-12  UrbanClimb Trousers Responsibility   Trousers
# 1  INV100001 2025-12-19        UrbanClimb Footwear Thousand   Footwear
# 2  INV100002 2024-02-10          NorthPeak Backpacks Garden  Backpacks
# 3  INV100003 2025-02-26            TrailPro Shirts Attorney     Shirts
# 4  INV100004 2025-05-09          UrbanClimb Backpacks Check  Backpacks
#
#    Gender       Brand StoreID        StoreName Region  UnitsSold  ...  \
# 0  Unisex  UrbanClimb    S007   South Outlet 7  South          2  ...
# 1     Men  UrbanClimb    S018  North Outlet 18  North          4  ...
# 2     Men   NorthPeak    S019   East Outlet 19   East          1  ...
# 3   Women    TrailPro    S008   North Outlet 8  North          1  ...
# 4     Men  UrbanClimb    S019   East Outlet 19   East          2  ...
#
#    DiscountPct  NetUnitPrice  GrossSales  NetSales  MarginPct  MarginValue  \
# ...
